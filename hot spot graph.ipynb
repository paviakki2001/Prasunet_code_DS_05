# %%
import pandas as pd
dataset=pd.read_csv(r"C:\Users\91936\Contacts\Downloads\archive (11)\NYC Accidents 2020.csv")
dataset.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  2020-08-29   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  2020-08-29   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  2020-08-29   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  2020-08-29   00:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  2020-08-29   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Correctly read the CSV file (make sure the path is correct)
dataset = pd.read_csv(r"C:\Users\91936\Contacts\Downloads\archive (11)\NYC Accidents 2020.csv")
print(dataset.head())  # To display the first few rows of the dataset

# Setting a seed for reproducibility
np.random.seed(0)

# Generating random data
data = np.random.rand(10, 12)  # 10 rows and 12 columns

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(data, annot=True, cmap="YlGnBu", linewidths=0.5)
plt.title('Accident HOTSPOT')
plt.xlabel('accident ')
plt.ylabel('contribution')
plt.show()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0  2020-08-29   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1  2020-08-29   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2  2020-08-29   18:20:00       NaN       NaN  40.81650 -73.946556
# 3  2020-08-29   00:00:00     BRONX   10459.0  40.82472 -73.892960
# 4  2020-08-29   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# ...
